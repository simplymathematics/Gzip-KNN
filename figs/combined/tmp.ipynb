# %%
import pandas as pd
import seaborn as sns

# Load the data
df = pd.read_csv('merged.csv')

import yaml


cols = df.columns.values
cols = cols.tolist()
cols.sort()
print(yaml.dump(cols))
# Out:
# - Condensing Method
# - Condensing Ratio
# - Dataset
# - Metric
# - Model
# - Symmetric
# - 'Unnamed: 0'
# - _target_
# - accuracy
# - data
# - data.drop
# - data.name
# - data.sample.random_state
# - data.sample.shuffle
# - data.sample.stratify
# - data.sample.test_size
# - data.sample.train_size
# - data.target
# - device_id
# - files
# - files._target_
# - files.data_dir
# - files.data_file
# - files.data_type
# - files.directory
# - files.name
# - files.predictions_file
# - files.reports
# - files.score_dict_file
# - files.stage
# - id
# - log_loss
# - model
# - model.data.drop
# - model.data.name
# - model.data.sample.random_state
# - model.data.sample.shuffle
# - model.data.sample.stratify
# - model.data.sample.test_size
# - model.data.sample.train_size
# - model.data.target
# - model.init.C
# - model.init.algorithm
# - model.init.class_weight
# - model.init.distance_matrix
# - model.init.fit_intercept
# - model.init.gamma
# - model.init.k
# - model.init.kernel
# ...

# %%
g = sns.catplot(
    data = df,
    x = "",
    y = "accuracy",
    hue = "model.init.modified",
    kind="boxen",
    col="Dataset",
    row="Model",
)
g.set_titles("{row_name} | {col_name}")
# Out:
# /Home/staff/cmeyers/deckard/env/lib/python3.11/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
